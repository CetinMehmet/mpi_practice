# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, re

# %%
OUTPUT_PATH = "/Users/c3t0/Desktop/openmpi_assignment/outputs/"
fill_types = ["asc", "rand"]
work_types = ["fixed", "imbalanced"]
nr_procs = ["1", "2", "4", "8"]

# %%
df = pd.DataFrame(columns={"nr_procs": 0, "fill_type": 0, "work_type": 0, "time": 0})
run = dict({"nr_procs": 0, "fill_type": 0, "work_type": 0, "time": 3})

for file in os.listdir(OUTPUT_PATH):
    file_path = OUTPUT_PATH + file
    f = open(file_path, "r", encoding='utf-8', errors='ignore')
    if f.readlines
    for line in f.readlines():
        print(line)
        if line != '\n':
            fill_type = re.findall(r'(rand|asc)', line)
            work_type = re.findall(r'imbalanced', line)
            nr_proc = re.findall(r'\d processors', line)
            time = float(line.split(":")[-1])

            run["fill_type"] = fill_type[0]
            run["work_type"] = work_type[0] if work_type != [] else "fixed"

            if nr_proc != []:
                run["nr_procs"] = int(nr_proc[0][0])
            else:
                run["nr_procs"] = 1

            run["time"] = time    
        
        df = df.append(run, ignore_index=True)
# Out:
# Time took to complete rand work with 8 processors: 62.398999
#
# Time took to complete rand work with 8 processors: 55.966773
#
# Time took to complete rand work with 8 processors: 60.606145
#
# Time took to complete rand work with 8 processors: 67.193671
#
# Time took to complete rand work with 8 processors: 61.126687
#
# Time took to complete rand work with 8 processors: 55.179363
#
# Time took to complete asc imbalanced work with 8 processors: 52.012333
#
# Time took to complete asc imbalanced work with 8 processors: 51.613239
#
# Time took to complete asc imbalanced work with 8 processors: 52.271856
#
# Time took to complete asc imbalanced work with 8 processors: 51.926736
#
# Time took to complete asc imbalanced work with 8 processors: 52.055912
#
# Time took to complete rand imbalanced work with 8 processors: 42.467709
#
# Time took to complete rand imbalanced work with 8 processors: 46.833472
#
# Time took to complete rand imbalanced work with 8 processors: 46.949205
#
# Time took to complete rand imbalanced work with 8 processors: 49.927079
#
# Time took to complete rand imbalanced work with 8 processors: 50.349463
#
# Time took to complete asc work with 8 processors: 65.184002
#
# Time took to complete asc work with 8 processors: 65.223320
#
# Time took to complete asc work with 8 processors: 65.270532
#
# Time took to complete asc work with 8 processors: 65.316986
#
# Time took to complete asc work with 8 processors: 65.652316
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/wb/1c2455fj7db13ry907z2qlgc0000gn/T/ipykernel_9375/1961424447.py in <module>
#       5     file_path = OUTPUT_PATH + file
#       6     f = open(file_path, "r")
# ----> 7     for line in f.readlines():
#       8         print(line)
#       9         if line != '\n':
#
# ~/miniforge3/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte

# %%
# Get the average per number of processor, work_type, and fill_type
df_avg = pd.DataFrame(columns={"nr_procs": 0, "fill_type": 0, "work_type": 0, "time": 0})
for nr_proc in nr_procs:
    for fill_type in fill_types:
        for work_type in work_types:
            avg_time = df[( df["work_type"] == work_type) & (df["fill_type"] == fill_type) & (df["nr_procs"] == int(nr_proc) )]["time"].mean(axis=0)
            df_avg = df_avg.append({"nr_procs": nr_proc, "fill_type": fill_type, "work_type": work_type, "time": avg_time}, ignore_index=True)
            
df_avg
# Out:
#    nr_procs fill_type   work_type        time
# 0         1       asc       fixed  442.244870
# 1         1       asc  imbalanced  353.461169
# 2         1      rand       fixed  328.780876
# 3         1      rand  imbalanced  349.869428
# 4         2       asc       fixed  173.951698
# 5         2       asc  imbalanced  181.990544
# 6         2      rand       fixed  195.380937
# 7         2      rand  imbalanced  169.510041
# 8         4       asc       fixed   92.844662
# 9         4       asc  imbalanced   94.468397
# 10        4      rand       fixed  113.729335
# 11        4      rand  imbalanced   90.667026
# 12        8       asc       fixed   65.329431
# 13        8       asc  imbalanced   51.976015
# 14        8      rand       fixed   60.411940
# 15        8      rand  imbalanced   47.305386

# %%
# speedup = time / p_time # (Time on 1 CPU) / (Time on p CPUs) 
# efficiency = speedup / p

df_eff = pd.DataFrame()

for fill_type in fill_types:
    for work_type in work_types:
        df_temp = df_avg[(df_avg["fill_type"] == fill_type) & (df_avg["work_type"] == work_type)]
        base_time = df_temp[df_temp['nr_procs'] == '1']['time'].values[0] 
        speedups = {
            '1': 1,
            '2': base_time / df_temp[df_temp['nr_procs'] == '2']['time'].values[0],
            '4': base_time / df_temp[df_temp['nr_procs'] == '4']['time'].values[0],
            '8': base_time / df_temp[df_temp['nr_procs'] == '8']['time'].values[0]
        }
        df_temp['efficiency'] = [speedups['1'], speedups['2'] / 2, speedups['4'] / 4, speedups['8'] / 8]
        df_temp['speedup'] = [speedups['1'], speedups['2'], speedups['4'], speedups['8']]
        df_eff = df_eff.append(df_temp, ignore_index=True)
        
df_eff
# Out:
# /var/folders/wb/1c2455fj7db13ry907z2qlgc0000gn/T/ipykernel_7179/1338319887.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['efficiency'] = [speedups['1'], speedups['2'] / 2, speedups['4'] / 4, speedups['8'] / 8]
#    nr_procs fill_type   work_type        time  efficiency
# 0         1       asc       fixed  442.244870    1.000000
# 1         2       asc       fixed  173.951698    1.271171
# 2         4       asc       fixed   92.844662    1.190819
# 3         8       asc       fixed   65.329431    0.846182
# 4         1       asc  imbalanced  353.461169    1.000000
# 5         2       asc  imbalanced  181.990544    0.971098
# 6         4       asc  imbalanced   94.468397    0.935395
# 7         8       asc  imbalanced   51.976015    0.850058
# 8         1      rand       fixed  328.780876    1.000000
# 9         2      rand       fixed  195.380937    0.841384
# 10        4      rand       fixed  113.729335    0.722727
# 11        8      rand       fixed   60.411940    0.680290
# 12        1      rand  imbalanced  349.869428    1.000000
# 13        2      rand  imbalanced  169.510041    1.032002
# 14        4      rand  imbalanced   90.667026    0.964710
# 15        8      rand  imbalanced   47.305386    0.924497

# %%
fig, ax = plt.subplots(1, 4, figsize=(24, 5), constrained_layout=True)

df_eff['nr_procs'] = [int(p) for p in df_eff['nr_procs'].values]

i = 0

for work_type in work_types:
    for fill_type in fill_types:
        df_temp = df_eff[(df_eff['work_type'] == work_type) & (df_eff['fill_type'] == fill_type)]
        ax[i].plot(df_temp["nr_procs"], df_temp['efficiency'], label=work_type + " " + fill_type)
        ax[i].set_xlabel("# Processors", fontsize=16)
        ax[i].set_ylabel("Efficiency relative to 1 processor", fontsize=16)
        ax[i].set_ylim(0, 1.5)
        ax[i].axhline(y=1, xmin=0, xmax=8, color='r', ls='dotted', label='100% efficiency')
        ax[i].legend(loc='upper right', fontsize=16)
        ax[i].tick_params(axis='both', which='major', labelsize=16)
        ax[i].tick_params(axis='both', which='minor', labelsize=14)
        i += 1
        
plt.savefig("efficiency_curve.pdf", dpi=100)
